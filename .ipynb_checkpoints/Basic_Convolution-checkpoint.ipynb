# %%
import thinkdsp 
import numpy 
import scipy
from scipy.io import wavfile

# %%
#This is the wave recorded by microphones. Assuming the impulse response is something like a loud clap. 
m_wave = thinkdsp.read_wave('92002__jcveliz__violin-origional.wav')
m_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#this is the recording of the impulse responses. Can be coppied for however long 
impulse = thinkdsp.read_wave('180961__kleeb__gunshots.wav')
impulse.make_audio()
# impulse_2 = wavfile.read('something else')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# halfed_impulse_1 = impulse_1
# halfed_impulse_2 = impulse_2*0.5

# %%
m_spectrum = m_wave.make_spectrum()
i_spectrum = impulse.make_spectrum()
print(m_spectrum)
print(i_spectrum)

# %%
out_spectrum = impulse*m_wave
# # out_wave = out_spectrum.make_wave()
# out_spectrum.make_audio()
# print(type(out_spectrum))

# make_wave(out_spectrum.ys, framerate = 44100)
# # out_wave_2 = numpy.convolve(halfed_impulse_2, microphone_wave)

# %%
out_wave.normalize()
out_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
scipy.io.wavfile.write(data, 'test.wav', 44100, out_array)
wave_rate, wave_data = wavfile.read('test.wav')
wave_data.play(data, 44100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-6c5a56978947> in <module>()
# ----> 1 scipy.io.wavfile.write(data, 'test.wav', 44100, out_array)
#       2 wave_rate, wave_data = wavfile.read('test.wav')
#       3 wave_data.play(data, 44100)
#
# NameError: name 'data' is not defined

# %%
out_wave = out_wave_1 + out_wave_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7f116b7d5f08> in <module>()
# ----> 1 out_wave = out_wave_1 + out_wave_2
#
# NameError: name 'out_wave_1' is not defined
